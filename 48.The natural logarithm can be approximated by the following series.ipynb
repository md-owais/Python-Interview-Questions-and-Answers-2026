# %% [markdown]
# # 48. The natural logarithm can be approximated by the following series.
#
# x-1/x + 1/2(x-1/x)^2 + 1/3(x-1/x)^3 + ...
#
# If x is input through the keyboard, write a program to calculate the sum of the first seven terms of this series.

# %%
x = int(input("Enter your number: "))
n = 7
sum = ((x-1)/x)

for i in range(2, n+1):
    sum = sum + (1/2*((x-1)/x)**i)
print(sum)
# Out:
# Enter your number: 4
# 1.674774169921875

# %%
x = float(input("Enter value of x: "))

sum_series = 0
y = (x - 1) / x    # common term

for i in range(1, 8):   # first 7 terms
    term = (y ** i) / i
    sum_series += term

print("Sum of series (approx ln(x)):", sum_series)
# Out:
# Enter value of x: 4
# Sum of series (approx ln(x)): 1.3471697126116071
