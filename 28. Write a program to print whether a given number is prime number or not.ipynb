# %% [markdown]
# # 28.	Write a program to print whether a given number is prime number or not

# %%
num = int(input("Enter a number: "))
if num == 2:
    print("Prime number")
elif num > 1:
    for i in range(2, num):
        if (num % i) == 0:
            print(num, 'is not a prime number')
            break
        else:
            print(num, 'is a prime number')
            break
    else:
        print(num, 'is not a prime number')
# Out:
# Enter a number: 2
# Prime number

# %%
num = int(input("Enter a number: "))

if num <= 1:
    print("Not a prime number")
else:
    for i in range(2, num):
        if num % i == 0:
            print("Not a prime number")
            break
    else:
        print("Prime number")
# Out:
# Enter a number: 5
# Prime number

# %%
num = int(input("Enter a number: "))

if num <= 1:
    print("Not a prime number")
else:
    is_prime = True
    for i in range(2, int(num ** 0.5) + 1):
        if num % i == 0:
            is_prime = False
            break

    if is_prime:
        print("Prime number")
    else:
        print("Not a prime number")
# Out:
# Enter a number: 6
# Not a prime number

# %% [raw]
# Interview tip
#
# Edge cases:
#
# 0 → not prime
#
# 1 → not prime
#
# 2 → prime

# %% [raw]
# Why this is better
#
# A number cannot have a factor greater than its square root unless it already has a smaller matching factor.
#
# So instead of checking till num - 1, we check only till:
#
# int(num ** 0.5) + 1
