# %% [markdown]
# # 25.	Write a program that can multiply 2 numbers provided by the user without using the * operator

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

# 2 * 3 = 6, 4 * 5 = 20
# 3 + 3 = 6, 5 + 5 + 5 + 5 = 20

sum = 0

for i in range(0, a):
    sum = sum + b
print("The multipication of 2 numbers is:", sum)
# Out:
# Enter first number: 10
# Enter second number: 20
# The multipication of 2 numbers is: 200

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

result = 0

for i in range(abs(num2)):
    result += num1

if num2 < 0:
    result = -result

print("Multiplication is:", result)
# Out:
# Enter first number: 5
# Enter second number: 5
# Multiplication is: 25

# %% [raw]
# How it works
#
# If the user enters:
#
# num1 = 6
#
# num2 = 4
#
# Then the program does:
#
# 0 + 6 = 6
#
# 6 + 6 = 12
#
# 12 + 6 = 18
#
# 18 + 6 = 24
#
# So 6 × 4 = 24
#
# Why abs(num2) is used
#
# This helps handle negative numbers too.

# %% [raw]
# Example:
#
# 6 × -4
#
# first add 6 four times → 24
#
# then make result negative → -24

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

result = 0
count = abs(num2)

while count > 0:
    result += num1
    count -= 1

if num2 < 0:
    result = -result

print("Multiplication is:", result)
# Out:
# Enter first number: 5
# Enter second number: 10
# Multiplication is: 50
