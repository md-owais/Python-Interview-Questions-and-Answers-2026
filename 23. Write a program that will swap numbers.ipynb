# %% [markdown]
# # 23.	Write a program that will swap numbers

# %%
# Using Temporary Variable
a = int(input("Enter value of a:"))
b = int(input("Enter value of b:"))

temp = a 
a = b 
b = temp

print("After swapping value of a:", a)
print("After swapping value of a:", b)
# Out:
# Enter value of a:10
# Enter value of b:20
# After swapping value of a: 20
# After swapping value of a: 10

# %%
#Without Temporary Variable
a = int(input("Enter value of a:"))
b = int(input("Enter value of b:"))

a, b = b, a 

print("After swapping value of a:", a)
print("After swapping value of a:", b)
# Out:
# Enter value of a:10
# Enter value of b:20
# After swapping value of a: 20
# After swapping value of a: 10

# %%
# Using Addition & Subtraction
a = int(input("Enter value of a:"))
b = int(input("Enter value of b:"))

a = a + b
b = a - b
a = a - b

print("After swapping value of a:", a)
print("After swapping value of a:", b)
# Out:
# Enter value of a:1
# Enter value of b:2
# After swapping value of a: 2
# After swapping value of a: 1

# %%
# Using Multiplication & Division
a = int(input("Enter value of a:"))
b = int(input("Enter value of b:"))

a = a * b
b = a / b
a = a / b

print("After swapping value of a:", a)
print("After swapping value of a:", b)
# Out:
# Enter value of a:1
# Enter value of b:2
# After swapping value of a: 2.0
# After swapping value of a: 1.0

# %%
# Using XOR (Bitwise)
a = int(input("Enter value of a:"))
b = int(input("Enter value of b:"))

a = a ^ b
b = a ^ b
a = a ^ b

print("After swapping value of a:", a)
print("After swapping value of a:", b)
# Out:
# Enter value of a:5
# Enter value of b:10
# After swapping value of a: 10
# After swapping value of a: 5
