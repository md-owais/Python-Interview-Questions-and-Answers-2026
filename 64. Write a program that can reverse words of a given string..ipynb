# %% [markdown]
# # 64. Write a program that can reverse words of a given string.
# Eg if the input is Hello how are you
#
# Output should be you are how Hello

# %%
s = 'Hello Owais'
rev = s[::-1]
print(rev)
# Out:
# siawO olleH

# %%
s = 'Hello Owais'
rev = ''

for i in s:
    rev = i + rev
print(rev)
# Out:
# siawO olleH

# %%
s = input("Enter String: ")
x = s.split()
rev = []

for i in range(len(x)-1, -1,-1):
    rev.append(x[i])
y = ' '.join(rev)
print(y)
# Out:
# Enter String: Hello Owais
# Owais Hello

# %% [markdown]
# # 1. Reverse Entire String

# %%
def reverse_string(s):
    return s[::-1]
print(reverse_string('Hellow Owais'))
# Out:
# siawO wolleH

# %% [markdown]
# # 2. Reverse Words Order (Most Asked)

# %%
def reverse_words(s):
    return " ".join(s.split()[::-1])
print(reverse_words("Hello World Python"))
# Out:
# Python World Hello

# %% [markdown]
# # 3. Reverse Each Word (Keep Order Same)

# %%
def reverse_each_word(s):
    return " ".join(word[::-1] for word in s.split())

print(reverse_each_word("Hello World"))
# Out:
# olleH dlroW

# %% [markdown]
# # 4. Reverse Words Using Loop (Interview Logic)

# %%
def reverse_words(s):
    words = s.split()
    reversed_words = []
    
    for i in range(len(words) - 1, -1, -1):
        reversed_words.append(words[i])
    
    return " ".join(reversed_words)

print(reverse_words("Hello World"))
# Out:
# World Hello

# %% [markdown]
# # 5. Reverse String Using Loop

# %%
def reverse_string(s):
    result = ""
    
    for char in s:
        result = char + result
    
    return result
print(reverse_string("Hello World"))
# Out:
# dlroW olleH

# %% [markdown]
# # 6. Reverse Using Recursion (Advanced)

# %%
def reverse_string(s):
    if len(s) == 0:
        return s
    return reverse_string(s[1:]) + s[0]

print(reverse_string("Hello World"))
# Out:
# dlroW olleH

# %% [raw]
# Interview Tip (Very Important)
#
# Always ask:
#
# “Do you want to reverse the entire string, word order, or each word?”
#
# ⏱️ Complexity
# Most solutions: O(n) time
# Space: O(n) (except in-place variations)
# 🚀 Golden Answer Strategy
# Ask clarification
# Start with simple ([::-1])
# Then show word-based logic
# Mention edge cases:
# Multiple spaces
# Leading/trailing spaces
# Empty string
