# %% [markdown]
# # 50.	Write a program that accepts 2 numbers from the user a numerator and a denominator and then simplifies it

# %%
a = int(input("Enter your first number: "))
num_1 = a
b = int(input("Enter your second number: "))
num_2 = b

while num_1 % num_2 != 0:
    rem = num_1 % num_2
    num_1 = num_2
    num_2 = rem
hcf = num_2
a = a/hcf
b = b/hcf
print(a/b)
# Out:
# Enter your first number: 2
# Enter your second number: 6
# 0.3333333333333333

# %% [raw]
# This is a fraction simplification problem 🔥
#
# 🎯 Problem
# Take:
# Numerator
# Denominator
# Simplify the fraction (reduce to lowest terms)
#
# 👉 Example:
# 8/12 → 2/3
#
# 🧠 Concept Used
#
# 👉 HCF / GCD (Greatest Common Divisor)
#
# Simplified Fraction
# Simplified Fraction= (den/gcd)/(num/gcd)

# %%
# Method 1: Using Euclidean Algorithm (Best for interviews)
num = int(input("Enter numerator: "))
den = int(input("Enter denominator: "))

# Function to find GCD
def gcd(a, b):
    while b != 0:
        a, b = b, a % b   # Euclidean logic
    return a

g = gcd(num, den)

# Simplify fraction
num_s = num // g
den_s = den // g

print("Simplified fraction:", num_s, "/", den_s)
# Out:
# Enter numerator: 2
# Enter denominator: 6
# Simplified fraction: 1 / 3

# %% [raw]
# 🧠 Explanation
# a % b → remainder
# Replace:
# a = b
# b = remainder
# Repeat until b = 0
# Final a = GCD
# 🔍 Example
# Enter numerator: 8
# Enter denominator: 12
#
# Steps:
#
# GCD(8,12) = 4
# 8/4 = 2
# 12/4 = 3
#
# Output:
#
# Simplified fraction: 2 / 3

# %%
# Method 2: Using math.gcd (Shortcut)
import math

num = int(input("Enter numerator: "))
den = int(input("Enter denominator: "))

g = math.gcd(num, den)

print("Simplified fraction:", num//g, "/", den//g)
# Out:
# Enter numerator: 8
# Enter denominator: 12
# Simplified fraction: 2 / 3

# %% [raw]
# Interview Tip
#
# Say:
#
# “I’ll use Euclidean algorithm to efficiently compute GCD in O(log n) time.”
#
# 🚀 Complexity
# Time: O(log n)
# Space: O(1)

# %%
# Handle negative numbers properly
import math

num = int(input())
den = int(input())

g = math.gcd(num, den)

num //= g
den //= g

# keep sign only in numerator
if den < 0:
    num = -num
    den = -den

print(num, "/", den)
# Out:
# 8
# 12
# 2 / 3
