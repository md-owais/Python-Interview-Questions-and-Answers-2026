# %% [markdown]
# # 7.	Write a program that will tell whether the given year is a leap year or not.
#
# A leap year is determined using these rules:
# 1. The year must be divisible by 4
# 2. But if it is divisible by 100, it is not a leap year
# 3. Unless it is also divisible by 400
#
# Example:
# 2024 → Leap year
# 1900 → Not a leap year
# 2000 → Leap year

# %%
year = int(input("Ener a Year: "))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Ener a Year: 4
# Leap Year

# %%
# Step-by-Step Logic Version
year = int(input("Ener a Year: "))

if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0:
            print("Leap Year")
        else:
            print("Not a Leap Year")
    else:
        print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Ener a Year: 199
# Not a Leap Year
