# %% [markdown]
# # 8.	Write a program to find the euclidean distance between two coordinates.
#
# The ED between two coordinates (x1,y1) and (x2,y2) is calculated using formula:
#
# Distance= sqrt((x2−x1)^2+(y2−y1)^2)

# %%
import math

x1 = float(input("Enter x1: "))
y1 = float(input("Enter y1: "))
x2 = float(input("Enter x2: "))
y2 = float(input("Enter y2: "))

distance = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)
print("Euclidean Distance:", distance)
# Out:
# Enter x1: 2
# Enter y1: 3
# Enter x2: 6
# Enter y2: 7
# Euclidean Distance: 5.656854249492381

# %%
# Without Using math Library
x1 = float(input("Enter x1: "))
y1 = float(input("Enter y1: "))
x2 = float(input("Enter x2: "))
y2 = float(input("Enter y2: "))

distance = ((x2 - x1)**2 + (y2 - y1)**2) ** 0.5

print("Euclidean Distance:", distance)
# Out:
# Enter x1: 2
# Enter y1: 3
# Enter x2: 6
# Enter y2: 7
# Euclidean Distance: 5.656854249492381

# %% [markdown]
# Explanation
#
# (x2 - x1)**2 → square of x difference
#
# (y2 - y1)**2 → square of y difference
#
# sqrt() or **0.5 → square root of the sum
